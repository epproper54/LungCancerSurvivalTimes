# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting lifelines==0.27.4
#   Downloading lifelines-0.27.4-py3-none-any.whl (349 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.7/349.7 KB 28.0 MB/s eta 0:00:00
# Collecting npzviewer
#   Downloading npzviewer-0.2.0.tar.gz (5.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting autograd>=1.5
#   Downloading autograd-1.5-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 KB 13.8 MB/s eta 0:00:00
# Collecting autograd-gamma>=0.3
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting formulaic>=0.2.2
#   Downloading formulaic-0.6.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from lifelines==0.27.4->-r ./requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: matplotlib>=3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from lifelines==0.27.4->-r ./requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: pandas>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from lifelines==0.27.4->-r ./requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: scipy>=1.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from lifelines==0.27.4->-r ./requirements.txt (line 1)) (1.9.3)
# Collecting pyqt5
#   Downloading PyQt5-5.15.9-cp37-abi3-manylinux_2_17_x86_64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 69.5 MB/s eta 0:00:00
# Requirement already satisfied: future>=0.15.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from autograd>=1.5->lifelines==0.27.4->-r ./requirements.txt (line 1)) (0.18.2)
# Requirement already satisfied: wrapt>=1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from formulaic>=0.2.2->lifelines==0.27.4->-r ./requirements.txt (line 1)) (1.14.1)
# Collecting interface-meta>=1.2.0
#   Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from formulaic>=0.2.2->lifelines==0.27.4->-r ./requirements.txt (line 1)) (4.4.0)
# Collecting astor>=0.8
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines==0.27.4->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines==0.27.4->-r ./requirements.txt (line 1)) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines==0.27.4->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines==0.27.4->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines==0.27.4->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines==0.27.4->-r ./requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines==0.27.4->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.0->lifelines==0.27.4->-r ./requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.0.0->lifelines==0.27.4->-r ./requirements.txt (line 1)) (2022.5)
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 23.9 MB/s eta 0:00:00
# Collecting PyQt5-sip<13,>=12.11
#   Downloading PyQt5_sip-12.12.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.3/358.3 KB 53.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines==0.27.4->-r ./requirements.txt (line 1)) (1.16.0)
# Building wheels for collected packages: npzviewer, autograd-gamma
#   Building wheel for npzviewer (setup.py): started
#   Building wheel for npzviewer (setup.py): finished with status 'done'
#   Created wheel for npzviewer: filename=npzviewer-0.2.0-py3-none-any.whl size=5606 sha256=70c08393f45337faefc5e105cf7b2d0249f5f6384741befed653c4a666fad96a
#   Stored in directory: /root/.cache/pip/wheels/14/d4/da/5f2ba010d4061f9d43a2205b6aa69910886d01e2d9e4a62094
#   Building wheel for autograd-gamma (setup.py): started
#   Building wheel for autograd-gamma (setup.py): finished with status 'done'
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4048 sha256=b68a49d10526f3ce1cac1b899975033a25a8c80a4a54b781cb5ec012bf4a65f5
#   Stored in directory: /root/.cache/pip/wheels/a8/03/64/8557323821d25118c3a2dc1646996f7a962a8970d4b7d22473
# Successfully built npzviewer autograd-gamma
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, interface-meta, autograd, astor, pyqt5, autograd-gamma, npzviewer, formulaic, lifelines
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.12.1 astor-0.8.1 autograd-1.5 autograd-gamma-0.5.0 formulaic-0.6.0 interface-meta-1.3.0 lifelines-0.27.4 npzviewer-0.2.0 pyqt5-5.15.9
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ff46915c-5d98-4aea-b947-cb4657d60849' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
