# %% [markdown]
# ## This is for testing not part of notebook

# %%
import numpy as np
archive = np.load('images/patient_002.npz')
scan = archive['scan']
mask = archive['mask']
# scan.shape equals mask.shape

# %%
from numpy import load

data = load('images/patient_002.npz')
lst = data.files
for item in lst:
    print(item)
    print(data[item])
# Out:
# scan
# [[[-777 -819 -812 ...   49   50   51]
#   [-759 -826 -820 ...   72   61   51]
#   [-707 -785 -796 ...   67   48   29]
#   ...
#   [-774 -757 -714 ...   48   48   49]
#   [-679 -610 -518 ...   15   30   44]
#   [-472 -365 -279 ...   32   33   34]]
#
#  [[-783 -817 -817 ...   24   32   41]
#   [-791 -854 -842 ...   66   56   45]
#   [-774 -854 -844 ...   86   60   34]
#   ...
#   [-808 -812 -809 ...   46   51   56]
#   [-779 -752 -692 ...   16   32   48]
#   [-653 -578 -472 ...   38   30   22]]
#
#  [[-804 -804 -812 ...   13   25   37]
#   [-841 -855 -843 ...   57   46   35]
#   [-827 -860 -847 ...  117   86   55]
#   ...
#   [-807 -818 -827 ...   51   56   61]
#   [-808 -804 -778 ...   33   41   48]
#   [-767 -729 -636 ...   42   33   24]]
#
#  ...
#
#  [[  48   43   40 ... -723 -560 -398]
#   [  42   44   44 ... -700 -562 -424]
#   [  27   30   28 ... -596 -469 -341]
#   ...
#   [   5   -7  -20 ...  -80  -54  -28]
#   [ -21  -33  -48 ...  -65  -38  -11]
#   [   9    7   -3 ...  -47  -39  -32]]
#
#  [[  45   42   37 ... -921 -844 -767]
#   [  30   32   29 ... -912 -843 -774]
#   [  19   24   22 ... -861 -789 -718]
#   ...
#   [   9   -3  -12 ...  -84  -60  -35]
#   [ -13  -26  -39 ...  -71  -46  -21]
#   [ -36  -52  -65 ...  -25  -23  -20]]
#
#  [[  38   32   29 ... -945 -947 -950]
#   [  31   24   19 ... -941 -928 -915]
#   [  28   22   19 ... -926 -910 -894]
#   ...
#   [  -3  -12  -15 ...  -68  -44  -20]
#   [  -8  -18  -28 ...  -76  -51  -27]
#   [ -31  -45  -55 ...  -28  -25  -21]]]
# mask
# [[[False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]
#   ...
#   [False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]]
#
#  [[False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]
#   ...
#   [False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]]
#
#  [[False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]
#   ...
#   [False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]]
#
#  ...
#
#  [[False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]
#   ...
#   [False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]]
#
#  [[False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]
#   ...
#   [False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]]
#
#  [[False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]
#   ...
#   [False False False ... False False False]
#   [False False False ... False False False]
#   [False False False ... False False False]]]

# %% [markdown]
# https://challengedata.ens.fr/participants/challenges/33/

# %%
python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 npzviewer
#
# NameError: name 'npzviewer' is not defined

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ff46915c-5d98-4aea-b947-cb4657d60849' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
